# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
demographics = pd.read_table('/Users/regi/Flatiron/mod5_project/ICPSR_25503/DS0001/25503-0001-Data.tsv')

# %%
demographics.columns.values
# Out:
# array(['SEQN', 'SDDSRVYR', 'RIDSTATR', 'RIDEXMON', 'RIAGENDR', 'RIDAGEYR',
#        'RIDAGEMN', 'RIDAGEEX', 'RIDRETH1', 'RIDRETH2', 'DMQMILIT',
#        'DMDBORN', 'DMDCITZN', 'DMDYRSUS', 'DMDEDUC3', 'DMDEDUC2',
#        'DMDEDUC', 'DMDSCHOL', 'DMDMARTL', 'DMDHHSIZ', 'INDHHINC',
#        'INDFMINC', 'INDFMPIR', 'RIDEXPRG', 'DMDHRGND', 'DMDHRAGE',
#        'DMDHRBRN', 'DMDHREDU', 'DMDHRMAR', 'DMDHSEDU', 'SIALANG',
#        'SIAPROXY', 'SIAINTRP', 'FIALANG', 'FIAPROXY', 'FIAINTRP',
#        'MIALANG', 'MIAPROXY', 'MIAINTRP', 'AIALANG', 'WTINT2YR',
#        'WTMEC2YR', 'SDMVPSU', 'SDMVSTRA'], dtype=object)

# %%
demographics[['DMDEDUC3', 'DMDEDUC2',
       'DMDEDUC', 'DMDSCHOL']]
# Out:
#       DMDEDUC3 DMDEDUC2 DMDEDUC DMDSCHOL
# 0           11                1        1
# 1           11                1        2
# 2            8                1        1
# 3           10                1        1
# 4                     3       2
# ...        ...      ...     ...      ...
# 10117
# 10118                 3       2
# 10119                 2       1
# 10120                 4       3
# 10121
#
# [10122 rows x 4 columns]

# %%
demographics
# Out:
#         SEQN  SDDSRVYR  RIDSTATR RIDEXMON  RIAGENDR  RIDAGEYR RIDAGEMN  \
# 0      21005         3         2        1         1        19      232
# 1      21006         3         2        2         2        16      203
# 2      21007         3         2        1         2        14      172
# 3      21008         3         2        2         1        17      208
# 4      21009         3         2        2         1        55      671
# ...      ...       ...       ...      ...       ...       ...      ...
# 10117  31122         3         2        2         2         5       66
# 10118  31123         3         2        2         2        83      996
# 10119  31124         3         2        1         1        44      537
# 10120  31125         3         2        1         1        54      652
# 10121  31126         3         2        2         1         1       14
#
#       RIDAGEEX  RIDRETH1  RIDRETH2 DMQMILIT  DMDBORN  DMDCITZN DMDYRSUS  \
# ...

# %%
demographics[['RIDRETH1','RIDRETH2']]
# Out:
#        RIDRETH1  RIDRETH2
# 0             4         2
# 1             4         2
# 2             3         1
# 3             4         2
# 4             3         1
# ...         ...       ...
# 10117         3         1
# 10118         3         1
# 10119         1         3
# 10120         3         1
# 10121         3         1
#
# [10122 rows x 2 columns]
